# %%
import os
os.chdir(r'c:\Users\calvi\Documents\Git\dsmp-2024-group-12\Calvin\dsmp-2024-group-12\Data')

# %%
import numpy as np
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_columns', None)

df_raw = pd.read_csv('vdjdb.txt', sep="	")
df_raw
# Out:
#        complex.id gene                  cdr3       v.segm      j.segm  \
# 0               1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1               1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3               2  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01
# 4               2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
# ...           ...  ...                   ...          ...         ...
# 92766       30592  TRB       CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01
# 92767       30593  TRA          CAPQGATNKLIF  TRAV12-2*01   TRAJ32*01
# 92768       30593  TRB       CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01
# 92769       30594  TRA        CLVGGSGGYNKLIF     TRAV4*01    TRAJ4*01
# 92770       30594  TRB         CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01
#
#            species           mhc.a           mhc.b mhc.class antigen.epitope  \
# 0      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 1      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 2      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 3      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 4      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# ...            ...             ...             ...       ...             ...
# 92766  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92767  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92768  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92769  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92770  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
#
#       antigen.gene antigen.species   reference.id  \
# 0              Nef           HIV-1  PMID:15596521
# 1              Nef           HIV-1  PMID:15596521
# 2              Nef           HIV-1  PMID:15596521
# 3              Nef           HIV-1  PMID:15596521
# 4              Nef           HIV-1  PMID:15596521
# ...            ...             ...            ...
# 92766       Gluten           Wheat  PMID:33927715
# 92767       Gluten           Wheat  PMID:33927715
# 92768       Gluten           Wheat  PMID:33927715
# 92769       Gluten           Wheat  PMID:33927715
# 92770       Gluten           Wheat  PMID:33927715
#
#                                                   method  \
# 0      {"frequency": "", "identification": "tetramer-...
# 1      {"frequency": "", "identification": "tetramer-...
# 2      {"frequency": "", "identification": "tetramer-...
# 3      {"frequency": "", "identification": "tetramer-...
# 4      {"frequency": "", "identification": "tetramer-...
# ...                                                  ...
# 92766  {"frequency": "", "identification": "tetramer-...
# 92767  {"frequency": "", "identification": "tetramer-...
# 92768  {"frequency": "", "identification": "tetramer-...
# 92769  {"frequency": "", "identification": "tetramer-...
# 92770  {"frequency": "", "identification": "tetramer-...
#
#                                                     meta  \
# 0      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 1      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 2      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 3      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 4      {"cell.subset": "CD8+", "clone.id": "", "donor...
# ...                                                  ...
# 92766  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92767  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92768  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92769  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92770  {"cell.subset": "CD4+", "clone.id": "", "donor...
#
#                                                  cdr3fix  vdjdb.score  \
# 0      {"cdr3": "CIVRAPGRADMRF", "cdr3_old": "CIVRAPG...            2
# 1      {"cdr3": "CASSYLPGQGDHYSNQPQHF", "cdr3_old": "...            2
# 2      {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...            2
# 3      {"cdr3": "CAVPSGAGSYQLTF", "cdr3_old": "CAVPSG...            2
# 4      {"cdr3": "CASSFEPGQGFYSNQPQHF", "cdr3_old": "C...            2
# ...                                                  ...          ...
# 92766  {"cdr3": "CASSPGQGGDNEQFF", "cdr3_old": "CASSP...            0
# 92767  {"cdr3": "CAPQGATNKLIF", "cdr3_old": "CAPQGATN...            2
# 92768  {"cdr3": "CASSLGAGGQETQYF", "cdr3_old": "CASSL...            2
# 92769  {"cdr3": "CLVGGSGGYNKLIF", "cdr3_old": "CLVGGS...            0
# 92770  {"cdr3": "CASSSTAQETQYF", "cdr3_old": "CASSSTA...            0
#
#       web.method web.method.seq web.cdr3fix.nc web.cdr3fix.unmp
# 0           sort         sanger             no               no
# 1           sort         sanger             no               no
# 2           sort         sanger             no               no
# 3           sort         sanger             no               no
# 4           sort         sanger             no               no
# ...          ...            ...            ...              ...
# 92766       sort     singlecell             no               no
# 92767       sort     singlecell             no               no
# 92768       sort     singlecell             no               no
# 92769       sort     singlecell             no               no
# 92770       sort     singlecell             no               no
#
# [92771 rows x 21 columns]

# %% [markdown]
# vdjdb.txt is a collapsed version of the VDJdb database used for annotation of single-chain TCR sequencing data by VDJdb-standalone software. Each line corresponds to either TCR alpha or TCR beta record as specified by the gene column.

# %%
fields = df_raw.columns
fields = pd.Series(index=fields)
fields['complex.id'] = 'TCR records coming from the same alpha-beta pair have the same index in complex.id column. In case complex.id is equal to 0 a record does not have either TCRalpha or TCRbeta chain information'
fields['gene'] = 'Corresponds to either TCR alpha or TCR beta record'
fields['cdr3'] = 'Fixed CDR3 sequence'
fields['v.segm'] = 'TCR V segment id'
fields['j.segm'] = 'TCR J segment id'
fields['species'] = 'TCR parent species'
fields['mhc.a'] = 'First MHC chain allele'
fields['mhc.b'] = 'Second MHC chain allele'
fields['mhc.class'] = 'MHCI or MHCII'
fields['antigen.epitope'] = 'Amino acid sequence of the epitope'
fields['antigen.gene'] = 'Parent gene of the epitope sequence'
fields['antigen.species'] = 'Parent species of the antigen'
fields['reference.id'] = 'Pubmed id'
fields['method'] = 'methods used to calculate a single confidence score based on various factors collapsed to a JSON string'
fields['meta'] = 'metadata collapsed to a JSON string'
fields['cdr3fix'] = 'In case of good V/J germline matching and errors in CDR3 sequence, the final CDR3 sequence in the database is replaced by its fixed version'
fields['vdjdb.score'] = 'At the final stage of database processing, TCR:peptide:MHC complexes are assigned with confidence scores. Scores are computed according to reported method entries.'
fields['meta'] = '???'
fields['web.method.seq'] = 'Sequencing method: sanger, rna-seq or amplicon-seq'
fields['web.cdr3fix.nc'] = '???'
fields['web.cdr3fix.unmp'] = '???'

fields
# Out:
# complex.id          TCR records coming from the same alpha-beta pa...
# gene                Corresponds to either TCR alpha or TCR beta re...
# cdr3                                              Fixed CDR3 sequence
# v.segm                                               TCR V segment id
# j.segm                                               TCR J segment id
# species                                            TCR parent species
# mhc.a                                          First MHC chain allele
# mhc.b                                         Second MHC chain allele
# mhc.class                                               MHCI or MHCII
# antigen.epitope                    Amino acid sequence of the epitope
# antigen.gene                      Parent gene of the epitope sequence
# antigen.species                         Parent species of the antigen
# reference.id                                                Pubmed id
# method              methods used to calculate a single confidence ...
# meta                                                              ???
# cdr3fix             In case of good V/J germline matching and erro...
# vdjdb.score         At the final stage of database processing, TCR...
# web.method                                                        NaN
# web.method.seq      Sequencing method: sanger, rna-seq or amplicon...
# web.cdr3fix.nc                                                    ???
# web.cdr3fix.unmp                                                  ???
# dtype: object

# %%
df_raw['mhc.class'].value_counts()
# Out:
# mhc.class
# MHCI     88368
# MHCII     4403
# Name: count, dtype: int64

# %%
fields.loc['antigen.gene':'web.cdr3fix.unmp'].index
# Out:
# Index(['antigen.gene', 'antigen.species', 'reference.id', 'method', 'meta',
#        'cdr3fix', 'vdjdb.score', 'web.method', 'web.method.seq',
#        'web.cdr3fix.nc', 'web.cdr3fix.unmp'],
#       dtype='object')

# %%
df = df_raw.drop(columns=fields.loc['reference.id':'cdr3fix'].index)
df = df.drop(columns=fields.loc['web.method':'web.cdr3fix.unmp'].index)
df
# Out:
#        complex.id gene                  cdr3       v.segm      j.segm  \
# 0               1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1               1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3               2  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01
# 4               2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
# ...           ...  ...                   ...          ...         ...
# 92766       30592  TRB       CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01
# 92767       30593  TRA          CAPQGATNKLIF  TRAV12-2*01   TRAJ32*01
# 92768       30593  TRB       CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01
# 92769       30594  TRA        CLVGGSGGYNKLIF     TRAV4*01    TRAJ4*01
# 92770       30594  TRB         CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01
#
#            species           mhc.a           mhc.b mhc.class antigen.epitope  \
# 0      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 1      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 2      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 3      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 4      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# ...            ...             ...             ...       ...             ...
# 92766  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92767  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92768  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92769  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92770  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
#
#       antigen.gene antigen.species  vdjdb.score
# 0              Nef           HIV-1            2
# 1              Nef           HIV-1            2
# 2              Nef           HIV-1            2
# 3              Nef           HIV-1            2
# 4              Nef           HIV-1            2
# ...            ...             ...          ...
# 92766       Gluten           Wheat            0
# 92767       Gluten           Wheat            2
# 92768       Gluten           Wheat            2
# 92769       Gluten           Wheat            0
# 92770       Gluten           Wheat            0
#
# [92771 rows x 13 columns]

# %%
df_alpha = df[df['gene'] == 'TRA']
df_beta = df[df['gene'] == 'TRB']
df_alpha
# Out:
#        complex.id gene            cdr3           v.segm     j.segm  \
# 0               1  TRA   CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01
# 3               2  TRA  CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01
# 5               3  TRA     CAVKASGSRLT         TRAV2*01        NaN
# 7               4  TRA   CAYRPPGTYKYIF  TRAV38-2/DV8*01  TRAJ40*01
# 9               5  TRA   CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01
# ...           ...  ...             ...              ...        ...
# 92761       30590  TRA   CMDEGGSNYKLTF      TRAV26-1*01  TRAJ53*01
# 92763       30591  TRA     CSLYNNNDMRF      TRAV26-1*01  TRAJ43*01
# 92765       30592  TRA   CALSTDSWGKLQF         TRAV6*01  TRAJ24*01
# 92767       30593  TRA    CAPQGATNKLIF      TRAV12-2*01  TRAJ32*01
# 92769       30594  TRA  CLVGGSGGYNKLIF         TRAV4*01   TRAJ4*01
#
#            species           mhc.a           mhc.b mhc.class antigen.epitope  \
# 0      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 3      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 5      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 7      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 9      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEQGGL
# ...            ...             ...             ...       ...             ...
# 92761  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII    PQPELPYPQPQL
# 92763  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII    PQPELPYPQPQL
# 92765  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92767  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92769  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
#
#       antigen.gene antigen.species  vdjdb.score
# 0              Nef           HIV-1            2
# 3              Nef           HIV-1            2
# 5              Nef           HIV-1            2
# 7              Nef           HIV-1            2
# 9              Nef           HIV-1            2
# ...            ...             ...          ...
# 92761       Gluten           Wheat            0
# 92763       Gluten           Wheat            0
# 92765       Gluten           Wheat            0
# 92767       Gluten           Wheat            2
# 92769       Gluten           Wheat            0
#
# [38049 rows x 13 columns]

# %%
with pd.option_context('display.max_rows', None):
    display(df_alpha[df_alpha['cdr3']=='CAASETSYDKVIF'])
# Out:
#        complex.id gene           cdr3       v.segm     j.segm      species  \
# 6496          800  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 26712        2876  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 26746        2893  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 26788        2914  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 27162        3101  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 27376        3208  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 28248        3644  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 28620        3830  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 28880        3960  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 29836        4438  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 29966        4503  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 30306        4673  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 30334        4687  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 31044        5042  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 31354        5197  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 32372        5706  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 32516        5778  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34070        6555  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34086        6563  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34114        6577  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34130        6585  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34154        6597  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34242        6641  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34274        6657  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34276        6658  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34396        6718  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34458        6749  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34532        6786  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34562        6801  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34572        6806  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34598        6819  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34724        6882  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34764        6902  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34878        6959  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34882        6961  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34908        6974  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 34972        7006  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 35032        7036  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 35170        7105  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 35190        7115  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 35226        7133  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 35392        7216  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 35472        7256  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 35524        7282  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 35570        7305  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 35648        7344  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 35678        7359  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 35726        7383  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 35756        7398  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 35800        7420  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 35944        7492  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 35976        7508  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36064        7552  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36106        7573  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36160        7600  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36192        7616  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36262        7651  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36354        7697  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36402        7721  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36422        7731  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36450        7745  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36480        7760  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36636        7838  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36642        7841  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36672        7856  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36736        7888  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36788        7914  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36940        7990  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36964        8002  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 36982        8011  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 37094        8067  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 37212        8126  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 37244        8142  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 37292        8166  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 37402        8221  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 37414        8227  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 37464        8252  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 37470        8255  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 37494        8267  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 37518        8279  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 37626        8333  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 37648        8344  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 37656        8348  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 37788        8414  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 37828        8434  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 37836        8438  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 37888        8464  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 38044        8542  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 38320        8680  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 38336        8688  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 38402        8721  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 38436        8738  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 38530        8785  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 38552        8796  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 38560        8800  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 38598        8819  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 38728        8884  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 38756        8898  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 38852        8946  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 38922        8981  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 38952        8996  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 38958        8999  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39044        9042  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39090        9065  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39126        9083  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39144        9092  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39264        9152  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39286        9163  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39358        9199  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39380        9210  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39384        9212  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39398        9219  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39400        9220  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39448        9244  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39498        9269  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39520        9280  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39702        9371  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39704        9372  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39734        9387  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39834        9437  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39914        9477  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39920        9480  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 39954        9497  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 40012        9526  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 40216        9628  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 40470        9755  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 40542        9791  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 40558        9799  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 40636        9838  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 40660        9850  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 40672        9856  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 40722        9881  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 40740        9890  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 40842        9941  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 40986       10013  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 40988       10014  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 41006       10023  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 41206       10123  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 41280       10160  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 41374       10207  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 41488       10264  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 41490       10265  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 41586       10313  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 41606       10323  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 41720       10380  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 41800       10420  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 41824       10432  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 41896       10468  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 41956       10498  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 41958       10499  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 41974       10507  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 42018       10529  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 42204       10622  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 42274       10657  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 42388       10714  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 42466       10753  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
# 42914       10977  TRA  CAASETSYDKVIF  TRAV13-1*01  TRAJ50*01  HomoSapiens
#
#              mhc.a mhc.b mhc.class antigen.epitope antigen.gene  \
# 6496   HLA-A*02:01   B2M      MHCI       NLVPMVATV         pp65
# 26712  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 26746  HLA-A*02:01   B2M      MHCI       GILGFVFTL            M
# 26788  HLA-A*02:01   B2M      MHCI       GILGFVFTL            M
# 27162  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 27376  HLA-A*03:01   B2M      MHCI       KLGGALQAK          IE1
# 28248  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 28620  HLA-A*11:01   B2M      MHCI       IVTDFSVIK        EBNA4
# 28880  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 29836  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 29966  HLA-A*11:01   B2M      MHCI      AVFDRKSDAK        EBNA4
# 30306  HLA-A*02:01   B2M      MHCI       GILGFVFTL            M
# 30334  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 31044  HLA-A*11:01   B2M      MHCI       IVTDFSVIK        EBNA4
# 31354  HLA-A*03:01   B2M      MHCI       KLGGALQAK          IE1
# 32372  HLA-A*11:01   B2M      MHCI      AVFDRKSDAK        EBNA4
# 32516  HLA-A*11:01   B2M      MHCI      AVFDRKSDAK        EBNA4
# 34070  HLA-A*11:01   B2M      MHCI       IVTDFSVIK        EBNA4
# 34086  HLA-A*11:01   B2M      MHCI       IVTDFSVIK        EBNA4
# 34114  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 34130  HLA-A*11:01   B2M      MHCI       IVTDFSVIK        EBNA4
# 34154  HLA-A*11:01   B2M      MHCI      AVFDRKSDAK        EBNA4
# 34242  HLA-A*11:01   B2M      MHCI      AVFDRKSDAK        EBNA4
# 34274  HLA-A*02:01   B2M      MHCI       GILGFVFTL            M
# 34276  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 34396  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 34458  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 34532  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 34562  HLA-A*02:01   B2M      MHCI       GILGFVFTL            M
# 34572  HLA-A*02:01   B2M      MHCI       GILGFVFTL            M
# 34598  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 34724  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 34764  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 34878  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 34882  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 34908  HLA-A*11:01   B2M      MHCI       IVTDFSVIK        EBNA4
# 34972  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 35032  HLA-A*03:01   B2M      MHCI       KLGGALQAK          IE1
# 35170  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 35190  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 35226  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 35392  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 35472  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 35524  HLA-A*02:01   B2M      MHCI       GLCTLVAML        BMLF1
# 35570  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 35648  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 35678  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 35726  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 35756  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 35800  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 35944  HLA-A*02:01   B2M      MHCI       GILGFVFTL            M
# 35976  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 36064  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 36106  HLA-A*11:01   B2M      MHCI      AVFDRKSDAK        EBNA4
# 36160  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 36192  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 36262  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 36354  HLA-A*02:01   B2M      MHCI       GILGFVFTL            M
# 36402  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 36422  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 36450  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 36480  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 36636  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 36642  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 36672  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 36736  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 36788  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 36940  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 36964  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 36982  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 37094  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 37212  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 37244  HLA-A*02:01   B2M      MHCI       GILGFVFTL            M
# 37292  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 37402  HLA-A*02:01   B2M      MHCI       GILGFVFTL            M
# 37414  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 37464  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 37470  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 37494  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 37518  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 37626  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 37648  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 37656  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 37788  HLA-A*02:01   B2M      MHCI       GILGFVFTL            M
# 37828  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 37836  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 37888  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 38044  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 38320  HLA-A*02:01   B2M      MHCI       GILGFVFTL            M
# 38336  HLA-A*03:01   B2M      MHCI       KLGGALQAK          IE1
# 38402  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 38436  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 38530  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 38552  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 38560  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 38598  HLA-A*03:01   B2M      MHCI       KLGGALQAK          IE1
# 38728  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 38756  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 38852  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 38922  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 38952  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 38958  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39044  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39090  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39126  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39144  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39264  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39286  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39358  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39380  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39384  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39398  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39400  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39448  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39498  HLA-A*02:01   B2M      MHCI       YLLEMLWRL         LMP1
# 39520  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39702  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39704  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39734  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39834  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39914  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39920  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 39954  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 40012  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 40216  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 40470  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 40542  HLA-A*11:01   B2M      MHCI      AVFDRKSDAK        EBNA4
# 40558  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 40636  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 40660  HLA-A*02:01   B2M      MHCI       GLCTLVAML        BMLF1
# 40672  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 40722  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 40740  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 40842  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 40986  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 40988  HLA-A*03:01   B2M      MHCI       KLGGALQAK          IE1
# 41006  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 41206  HLA-A*03:01   B2M      MHCI       KLGGALQAK          IE1
# 41280  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 41374  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 41488  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 41490  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 41586  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 41606  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 41720  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 41800  HLA-A*03:01   B2M      MHCI       KLGGALQAK          IE1
# 41824  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 41896  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 41956  HLA-A*03:01   B2M      MHCI       KLGGALQAK          IE1
# 41958  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 41974  HLA-A*11:01   B2M      MHCI      AVFDRKSDAK        EBNA4
# 42018  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 42204  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 42274  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 42388  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 42466  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
# 42914  HLA-B*08:01   B2M      MHCI        RAKFKQLL        BZLF1
#
#       antigen.species  vdjdb.score
# 6496              CMV            3
# 26712             EBV            0
# 26746      InfluenzaA            0
# 26788      InfluenzaA            0
# 27162             EBV            0
# 27376             CMV            0
# 28248             EBV            1
# 28620             EBV            0
# 28880             EBV            0
# 29836             EBV            0
# 29966             EBV            0
# 30306      InfluenzaA            0
# 30334             EBV            0
# 31044             EBV            0
# 31354             CMV            0
# 32372             EBV            0
# 32516             EBV            0
# 34070             EBV            0
# 34086             EBV            0
# 34114             EBV            0
# 34130             EBV            0
# 34154             EBV            0
# 34242             EBV            0
# 34274      InfluenzaA            0
# 34276             EBV            0
# 34396             EBV            0
# 34458             EBV            1
# 34532             EBV            0
# 34562      InfluenzaA            0
# 34572      InfluenzaA            0
# 34598             EBV            0
# 34724             EBV            0
# 34764             EBV            0
# 34878             EBV            0
# 34882             EBV            0
# 34908             EBV            0
# 34972             EBV            0
# 35032             CMV            0
# 35170             EBV            0
# 35190             EBV            0
# 35226             EBV            0
# 35392             EBV            0
# 35472             EBV            0
# 35524             EBV            0
# 35570             EBV            0
# 35648             EBV            0
# 35678             EBV            0
# 35726             EBV            0
# 35756             EBV            0
# 35800             EBV            0
# 35944      InfluenzaA            0
# 35976             EBV            0
# 36064             EBV            0
# 36106             EBV            0
# 36160             EBV            0
# 36192             EBV            0
# 36262             EBV            0
# 36354      InfluenzaA            0
# 36402             EBV            0
# 36422             EBV            0
# 36450             EBV            0
# 36480             EBV            0
# 36636             EBV            0
# 36642             EBV            0
# 36672             EBV            0
# 36736             EBV            0
# 36788             EBV            0
# 36940             EBV            0
# 36964             EBV            0
# 36982             EBV            0
# 37094             EBV            0
# 37212             EBV            0
# 37244      InfluenzaA            0
# 37292             EBV            0
# 37402      InfluenzaA            0
# 37414             EBV            0
# 37464             EBV            0
# 37470             EBV            0
# 37494             EBV            0
# 37518             EBV            0
# 37626             EBV            0
# 37648             EBV            0
# 37656             EBV            0
# 37788      InfluenzaA            0
# 37828             EBV            0
# 37836             EBV            0
# 37888             EBV            0
# 38044             EBV            0
# 38320      InfluenzaA            0
# 38336             CMV            0
# 38402             EBV            0
# 38436             EBV            0
# 38530             EBV            0
# 38552             EBV            0
# 38560             EBV            0
# 38598             CMV            0
# 38728             EBV            0
# 38756             EBV            0
# 38852             EBV            0
# 38922             EBV            0
# 38952             EBV            0
# 38958             EBV            0
# 39044             EBV            0
# 39090             EBV            0
# 39126             EBV            0
# 39144             EBV            0
# 39264             EBV            0
# 39286             EBV            0
# 39358             EBV            0
# 39380             EBV            0
# 39384             EBV            0
# 39398             EBV            0
# 39400             EBV            0
# 39448             EBV            0
# 39498             EBV            0
# 39520             EBV            0
# 39702             EBV            0
# 39704             EBV            0
# 39734             EBV            0
# 39834             EBV            0
# 39914             EBV            0
# 39920             EBV            0
# 39954             EBV            0
# 40012             EBV            0
# 40216             EBV            0
# 40470             EBV            0
# 40542             EBV            0
# 40558             EBV            0
# 40636             EBV            0
# 40660             EBV            0
# 40672             EBV            0
# 40722             EBV            0
# 40740             EBV            0
# 40842             EBV            0
# 40986             EBV            0
# 40988             CMV            0
# 41006             EBV            0
# 41206             CMV            0
# 41280             EBV            0
# 41374             EBV            0
# 41488             EBV            0
# 41490             EBV            0
# 41586             EBV            0
# 41606             EBV            0
# 41720             EBV            0
# 41800             CMV            0
# 41824             EBV            0
# 41896             EBV            0
# 41956             CMV            0
# 41958             EBV            0
# 41974             EBV            0
# 42018             EBV            0
# 42204             EBV            0
# 42274             EBV            0
# 42388             EBV            0
# 42466             EBV            0
# 42914             EBV            0
