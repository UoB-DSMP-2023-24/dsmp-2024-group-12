# %%
import os
os.chdir(r'c:\Users\calvi\Documents\Git\dsmp-2024-group-12\Calvins Stuff')

# %%
import numpy as np
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_columns', None)

df_raw = pd.read_csv('vdjdb.txt', sep="	")
df_raw
# Out:
#        complex.id gene                  cdr3       v.segm      j.segm  \
# 0               1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1               1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3               2  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01
# 4               2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
# ...           ...  ...                   ...          ...         ...
# 92766       30592  TRB       CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01
# 92767       30593  TRA          CAPQGATNKLIF  TRAV12-2*01   TRAJ32*01
# 92768       30593  TRB       CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01
# 92769       30594  TRA        CLVGGSGGYNKLIF     TRAV4*01    TRAJ4*01
# 92770       30594  TRB         CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01
#
#            species           mhc.a           mhc.b mhc.class antigen.epitope  \
# 0      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 1      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 2      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 3      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 4      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# ...            ...             ...             ...       ...             ...
# 92766  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92767  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92768  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92769  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92770  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
#
#       antigen.gene antigen.species   reference.id  \
# 0              Nef           HIV-1  PMID:15596521
# 1              Nef           HIV-1  PMID:15596521
# 2              Nef           HIV-1  PMID:15596521
# 3              Nef           HIV-1  PMID:15596521
# 4              Nef           HIV-1  PMID:15596521
# ...            ...             ...            ...
# 92766       Gluten           Wheat  PMID:33927715
# 92767       Gluten           Wheat  PMID:33927715
# 92768       Gluten           Wheat  PMID:33927715
# 92769       Gluten           Wheat  PMID:33927715
# 92770       Gluten           Wheat  PMID:33927715
#
#                                                   method  \
# 0      {"frequency": "", "identification": "tetramer-...
# 1      {"frequency": "", "identification": "tetramer-...
# 2      {"frequency": "", "identification": "tetramer-...
# 3      {"frequency": "", "identification": "tetramer-...
# 4      {"frequency": "", "identification": "tetramer-...
# ...                                                  ...
# 92766  {"frequency": "", "identification": "tetramer-...
# 92767  {"frequency": "", "identification": "tetramer-...
# 92768  {"frequency": "", "identification": "tetramer-...
# 92769  {"frequency": "", "identification": "tetramer-...
# 92770  {"frequency": "", "identification": "tetramer-...
#
#                                                     meta  \
# 0      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 1      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 2      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 3      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 4      {"cell.subset": "CD8+", "clone.id": "", "donor...
# ...                                                  ...
# 92766  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92767  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92768  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92769  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92770  {"cell.subset": "CD4+", "clone.id": "", "donor...
#
#                                                  cdr3fix  vdjdb.score  \
# 0      {"cdr3": "CIVRAPGRADMRF", "cdr3_old": "CIVRAPG...            2
# 1      {"cdr3": "CASSYLPGQGDHYSNQPQHF", "cdr3_old": "...            2
# 2      {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...            2
# 3      {"cdr3": "CAVPSGAGSYQLTF", "cdr3_old": "CAVPSG...            2
# 4      {"cdr3": "CASSFEPGQGFYSNQPQHF", "cdr3_old": "C...            2
# ...                                                  ...          ...
# 92766  {"cdr3": "CASSPGQGGDNEQFF", "cdr3_old": "CASSP...            0
# 92767  {"cdr3": "CAPQGATNKLIF", "cdr3_old": "CAPQGATN...            2
# 92768  {"cdr3": "CASSLGAGGQETQYF", "cdr3_old": "CASSL...            2
# 92769  {"cdr3": "CLVGGSGGYNKLIF", "cdr3_old": "CLVGGS...            0
# 92770  {"cdr3": "CASSSTAQETQYF", "cdr3_old": "CASSSTA...            0
#
#       web.method web.method.seq web.cdr3fix.nc web.cdr3fix.unmp
# 0           sort         sanger             no               no
# 1           sort         sanger             no               no
# 2           sort         sanger             no               no
# 3           sort         sanger             no               no
# 4           sort         sanger             no               no
# ...          ...            ...            ...              ...
# 92766       sort     singlecell             no               no
# 92767       sort     singlecell             no               no
# 92768       sort     singlecell             no               no
# 92769       sort     singlecell             no               no
# 92770       sort     singlecell             no               no
#
# [92771 rows x 21 columns]

# %% [markdown]
# vdjdb.txt is a collapsed version of the VDJdb database used for annotation of single-chain TCR sequencing data by VDJdb-standalone software. Each line corresponds to either TCR alpha or TCR beta record as specified by the gene column.

# %%
fields = df_raw.columns
fields = pd.Series(index=fields)
fields['complex.id'] = 'TCR records coming from the same alpha-beta pair have the same index in complex.id column. In case complex.id is equal to 0 a record does not have either TCRalpha or TCRbeta chain information'
fields['gene'] = 'Corresponds to either TCR alpha or TCR beta record'
fields['cdr3'] = 'Fixed CDR3 sequence'
fields['v.segm'] = 'TCR V segment id'
fields['j.segm'] = 'TCR J segment id'
fields['species'] = 'TCR parent species'
fields['mhc.a'] = 'First MHC chain allele'
fields['mhc.b'] = 'Second MHC chain allele'
fields['mhc.class'] = 'MHCI or MHCII'
fields['antigen.epitope'] = 'Amino acid sequence of the epitope'
fields['antigen.gene'] = 'Parent gene of the epitope sequence'
fields['antigen.species'] = 'Parent species of the antigen'
fields['reference.id'] = 'Pubmed id'
fields['method'] = 'methods used to calculate a single confidence score based on various factors collapsed to a JSON string'
fields['meta'] = 'metadata collapsed to a JSON string'
fields['cdr3fix'] = 'In case of good V/J germline matching and errors in CDR3 sequence, the final CDR3 sequence in the database is replaced by its fixed version'
fields['vdjdb.score'] = 'At the final stage of database processing, TCR:peptide:MHC complexes are assigned with confidence scores. Scores are computed according to reported method entries.'
fields['meta'] = '???'
fields['web.method.seq'] = 'Sequencing method: sanger, rna-seq or amplicon-seq'
fields['web.cdr3fix.nc'] = '???'
fields['web.cdr3fix.unmp'] = '???'

fields
# Out:
# complex.id          TCR records coming from the same alpha-beta pa...
# gene                Corresponds to either TCR alpha or TCR beta re...
# cdr3                                              Fixed CDR3 sequence
# v.segm                                               TCR V segment id
# j.segm                                               TCR J segment id
# species                                            TCR parent species
# mhc.a                                          First MHC chain allele
# mhc.b                                         Second MHC chain allele
# mhc.class                                               MHCI or MHCII
# antigen.epitope                    Amino acid sequence of the epitope
# antigen.gene                      Parent gene of the epitope sequence
# antigen.species                         Parent species of the antigen
# reference.id                                                Pubmed id
# method              methods used to calculate a single confidence ...
# meta                                                              ???
# cdr3fix             In case of good V/J germline matching and erro...
# vdjdb.score         At the final stage of database processing, TCR...
# web.method                                                        NaN
# web.method.seq      Sequencing method: sanger, rna-seq or amplicon...
# web.cdr3fix.nc                                                    ???
# web.cdr3fix.unmp                                                  ???
# dtype: object

# %%
df_raw['mhc.class'].value_counts()
# Out:
# MHCI     88368
# MHCII     4403
# Name: mhc.class, dtype: int64

# %%
fields.loc['reference.id':'web.cdr3fix.unmp'].index
# Out:
# Index(['reference.id', 'method', 'meta', 'cdr3fix', 'vdjdb.score',
#        'web.method', 'web.method.seq', 'web.cdr3fix.nc', 'web.cdr3fix.unmp'],
#       dtype='object')

# %%
df_ref = df_raw.drop(columns=fields.loc['reference.id':'web.cdr3fix.unmp'].index)
df_ref.sample(30)
# Out:
#        complex.id gene               cdr3         v.segm      j.segm  \
# 26955        2997  TRB       CSASPGDYEQYF    TRBV20-1*01  TRBJ2-7*01
# 1435          188  TRA       CIVLGGADGLTF    TRAV26-1*01   TRAJ45*01
# 29076        4058  TRA       CAESGGTDKLIF       TRAV5*01   TRAJ34*01
# 6277          690  TRB      CASSLVGTGELFF     TRBV7-3*01  TRBJ2-2*01
# 14627           0  TRA      CAASGQAGTALIF  TRAV29/DV5*01   TRAJ15*01
# 7248            0  TRA   CAGLWDRGSTLGRLYF      TRAV35*01   TRAJ18*01
# 66569       22804  TRB    CASSLSRREGHEQFF      TRBV27*01  TRBJ2-1*01
# 40331        9685  TRB    CASSRAGRSTDTQYF    TRBV11-2*01  TRBJ2-3*01
# 17299        1079  TRA       CAAGGSQGNLIF     TRAV8-6*01   TRAJ42*01
# 23192        1860  TRB    CASSLDRQGFGELFF     TRBV7-7*01  TRBJ2-2*01
# 44479       11759  TRB     CASSAGGRGTEAFF     TRBV6-6*01  TRBJ1-1*01
# 7046         1031  TRB     CASSAQGDSYEQYF     TRBV4-3*01  TRBJ2-7*01
# 62437       20738  TRB  CASSQRLSGRRKNIQYF     TRBV4-1*01  TRBJ2-4*01
# 85893       28327  TRB     CASSSDPSTDTQYF      TRBV27*01  TRBJ2-3*01
# 75192           0  TRB     CASSPGQLANEQFF     TRBV4-3*01  TRBJ2-1*01
# 2920            0  TRB    CASRPDRGGWQPQHF    TRBV12-3*01  TRBJ1-5*01
# 46456       12748  TRA     CAECPQKGSYIPTF       TRAV5*01    TRAJ6*01
# 71826       25265  TRA      CAVSDNYAQGLTF    TRAV3N-3*01   TRAJ26*01
# 18844           0  TRB     CASSSTETGTEAFF     TRBV7-9*01  TRBJ1-1*01
# 45747       12393  TRB     CASSPETGGETQYF     TRBV5-6*01  TRBJ2-5*01
# 2428            0  TRB  CASSPQRRLAGGDTQYF      TRBV27*01  TRBJ2-3*01
# 60421       19730  TRB    CASSHGGISYNEQFF     TRBV6-1*01  TRBJ2-1*01
# 15011           0  TRA    CALSVRHTGGFKTIF      TRAV19*01    TRAJ9*01
# 42100       10570  TRA      CAVDSNSGYALNF       TRAV2*01   TRAJ41*01
# 19972           0  TRB       CASSSLNTEAFF      TRBV27*01  TRBJ1-1*01
# 91799       30313  TRA    CAGQNYGGSQGNLIF      TRAV35*01   TRAJ42*01
# 65724       22382  TRA    CAVDLMKTSYDKVIF      TRAV21*01   TRAJ50*01
# 22873           0  TRB    CAISDSEASTDTQYF    TRBV10-3*02  TRBJ2-3*01
# 92023       30406  TRB  CASSLTRGTASLYGYTF      TRBV27*01  TRBJ1-2*01
# 2936            0  TRB   CASSADERGGSYEQYF       TRBV9*01  TRBJ2-7*01
#
#            species                 mhc.a              mhc.b mhc.class  \
# 26955  HomoSapiens           HLA-A*11:01                B2M      MHCI
# 1435   HomoSapiens  HLA-DQA1*05:01:01:02  HLA-DQB1*02:01:08     MHCII
# 29076  HomoSapiens           HLA-A*03:01                B2M      MHCI
# 6277   HomoSapiens           HLA-A*02:01                B2M      MHCI
# 14627  HomoSapiens              HLA-A*02                B2M      MHCI
# 7248   HomoSapiens              HLA-A*02                B2M      MHCI
# 66569  HomoSapiens           HLA-A*11:01                B2M      MHCI
# 40331  HomoSapiens           HLA-A*03:01                B2M      MHCI
# 17299  HomoSapiens              HLA-A*02                B2M      MHCI
# 23192  HomoSapiens           HLA-B*57:01                B2M      MHCI
# 44479  HomoSapiens           HLA-A*03:01                B2M      MHCI
# 7046   HomoSapiens           HLA-A*02:01                B2M      MHCI
# 62437  HomoSapiens           HLA-A*03:01                B2M      MHCI
# 85893  HomoSapiens           HLA-A*01:01                B2M      MHCI
# 75192  HomoSapiens              HLA-B*27                B2M      MHCI
# 2920   HomoSapiens              HLA-A*02                B2M      MHCI
# 46456  HomoSapiens           HLA-A*03:01                B2M      MHCI
# 71826  MusMusculus                 H-2Kb                B2M      MHCI
# 18844  HomoSapiens           HLA-A*02:01                B2M      MHCI
# 45747  HomoSapiens           HLA-A*03:01                B2M      MHCI
# 2428   HomoSapiens              HLA-A*02                B2M      MHCI
# 60421  HomoSapiens           HLA-A*03:01                B2M      MHCI
# 15011  HomoSapiens              HLA-A*02                B2M      MHCI
# 42100  HomoSapiens           HLA-A*11:01                B2M      MHCI
# 19972  HomoSapiens           HLA-B*08:01                B2M      MHCI
# 91799  HomoSapiens         HLA-DPA*01:03      HLA-DPB*04:01     MHCII
# 65724  HomoSapiens           HLA-A*11:01                B2M      MHCI
# 22873  HomoSapiens           HLA-A*02:01                B2M      MHCI
# 92023  HomoSapiens         HLA-DPA*01:03      HLA-DPB*04:01     MHCII
# 2936   HomoSapiens              HLA-A*02                B2M      MHCI
#
#       antigen.epitope antigen.gene   antigen.species
# 26955       IVTDFSVIK        EBNA4               EBV
# 1435    APQPELPYPQPGS          NaN  TriticumAestivum
# 29076       KLGGALQAK          IE1               CMV
# 6277        NLVPMVATV         pp65               CMV
# 14627       GILGFVFTL            M        InfluenzaA
# 7248        NLVPMVATV         pp65               CMV
# 66569       IVTDFSVIK        EBNA4               EBV
# 40331       KLGGALQAK          IE1               CMV
# 17299       GILGFVFTL            M        InfluenzaA
# 23192       KSKRTPMGF         NS5B               HCV
# 44479       KLGGALQAK          IE1               CMV
# 7046        LLWNGPMAV         NS4B               YFV
# 62437       RLRAEAQVK       EBNA3A               EBV
# 85893       VIYMGTLSY       ORF1ab        SARS-CoV-2
# 75192      KRWIILGLNK          Gag             HIV-1
# 2920       ELAGIGILTV        MLANA       HomoSapiens
# 46456       KLGGALQAK          IE1               CMV
# 71826       SSYRRPVGI          PB1        InfluenzaA
# 18844       GLCTLVAML        BMLF1               EBV
# 45747       KLGGALQAK          IE1               CMV
# 2428       ELAGIGILTV        MLANA       HomoSapiens
# 60421       KLGGALQAK          IE1               CMV
# 15011       GILGFVFTL            M        InfluenzaA
# 42100       IVTDFSVIK        EBNA4               EBV
# 19972        RAKFKQLL        BZLF1               EBV
# 91799  TFEYVSQPFLMDLE        Spike        SARS-CoV-2
# 65724       IVTDFSVIK        EBNA4               EBV
# 22873       CINGVCWTV          NS3               HCV
# 92023  TFEYVSQPFLMDLE        Spike        SARS-CoV-2
# 2936       ELAGIGILTV        MLANA       HomoSapiens

# %%
df = df_ref.drop(columns=['species','antigen.gene','antigen.species'])
df.sample(30)
# Out:
#        complex.id gene              cdr3         v.segm      j.segm  \
# 79743           0  TRB  CASSSLHSATNEKLFF    TRBV12-4*01  TRBJ1-4*01
# 22980        1774  TRA       CLVGPNARLMF       TRAV4*01   TRAJ31*01
# 88773           0  TRA       CVVNILNDMRF    TRAV12-1*01   TRAJ43*01
# 4678            0  TRB     CASSFLPKNEQFF     TRBV7-2*01  TRBJ2-1*01
# 1792            0  TRB    CASRDSAVTGELFF     TRBV6-4*01  TRBJ2-2*01
# 91758       30296  TRA     CAVPAYNNNDMRF      TRAV21*01   TRAJ43*01
# 21760           0  TRB   CASSIVGHMNTEAFF      TRBV19*01  TRBJ1-1*01
# 10940           0  TRB    CASSYAAGDNEQFF     TRBV6-2*01  TRBJ2-1*01
# 79603           0  TRB  CSARDLQGAYNSPLHF    TRBV20-1*01  TRBJ1-6*01
# 22295           0  TRA   CLVGDITGGSYIPTF       TRAV4*01    TRAJ6*01
# 18056           0  TRB   CASSQGRGRNTEAFF     TRBV4-3*01  TRBJ1-1*01
# 22484           0  TRA   CLVGDLTGGSYIPTF       TRAV4*01    TRAJ6*01
# 24507        2404  TRA  CALLDLTGAGSYQLTF      TRAV19*01   TRAJ28*01
# 84937       27904  TRB     CASSDRAGNTIYF      TRBV19*01  TRBJ1-3*01
# 6071          587  TRB   CASSVEGQGDTEAFF       TRBV9*01  TRBJ1-1*01
# 56050       17545  TRA    CAATTNTGFQKLVF    TRAV13-1*01    TRAJ8*01
# 39555        9297  TRB   CASSLAQASTDTQYF     TRBV7-9*01  TRBJ2-3*01
# 69208       23956  TRA    CAGGGSSNTGKLIF      TRAV27*01   TRAJ37*01
# 87661           0  TRB    CASSWGQGEETQYF     TRBV5-1*01  TRBJ2-5*01
# 85839       28300  TRB   CSARDRTGVKNIQYF    TRBV20-1*01  TRBJ2-4*01
# 49250       14145  TRA  CAMRGPISGGYNKLIF  TRAV14/DV4*01    TRAJ4*01
# 81316           0  TRB   CASSKQGNSNQPQYF      TRBV15*01  TRBJ1-5*01
# 19743        1433  TRB   CASTGLGRGGTEAFF      TRBV28*01  TRBJ1-1*01
# 967             0  TRB   CASSYQTGAAYGYTF     TRBV6-5*01  TRBJ1-2*01
# 42436       10738  TRA      CALSRTGNQFYF      TRAV16*01   TRAJ49*01
# 17876           0  TRB       CASTGGSGYTF      TRBV13*01  TRBJ1-2*01
# 5363            0  TRB     CASSLGPDNEQFF    TRBV11-2*01  TRBJ2-1*01
# 84070           0  TRB    CASSQASPGDEQFF     TRBV4-2*01  TRBJ2-1*01
# 46270       12655  TRA  CIVRVAGQTGANNLFF    TRAV26-1*01   TRAJ36*01
# 28305        3672  TRB   CASSVRSSMNTEAFF       TRBV9*01  TRBJ1-1*01
#
#                mhc.a           mhc.b mhc.class   antigen.epitope
# 79743     HLA-DRA*01     HLA-DRB1*01     MHCII    SGPLKAEIAQRLED
# 22980    HLA-A*02:01             B2M      MHCI         CINGVCWTV
# 88773       HLA-A*02             B2M      MHCI         YLQPRTFLL
# 4678        HLA-B*08             B2M      MHCI          EIYKRWII
# 1792        HLA-A*02             B2M      MHCI        ELAGIGILTV
# 91758    HLA-A*01:01             B2M      MHCI        TTDPSFLGRY
# 21760       HLA-B*27             B2M      MHCI         ARMILMTHF
# 10940       HLA-A*02             B2M      MHCI         NLVPMVATV
# 79603     HLA-DRA*01     HLA-DRB1*01     MHCII  QARQMVQAMRTIGTHP
# 22295       HLA-B*44             B2M      MHCI          NEGVKAAW
# 18056    HLA-A*01:01             B2M      MHCI         VTEHDTLLY
# 22484       HLA-B*44             B2M      MHCI          NEGVKAAW
# 24507    HLA-A*24:01             B2M      MHCI         QYIKWPWYI
# 84937    HLA-A*02:01             B2M      MHCI         GILGFVFTL
# 6071     HLA-A*02:01             B2M      MHCI         NLVPMVATV
# 56050    HLA-A*03:01             B2M      MHCI         KLGGALQAK
# 39555    HLA-A*03:01             B2M      MHCI         KLGGALQAK
# 69208    HLA-A*02:01             B2M      MHCI         GILGFVFTL
# 87661    HLA-A*02:01             B2M      MHCI         SIWNLDYII
# 85839    HLA-A*01:01             B2M      MHCI         YADVFHLYL
# 49250    HLA-A*03:01             B2M      MHCI         KLGGALQAK
# 81316      Mamu-A*01             B2M      MHCI         CTPYDINQM
# 19743  HLA-DRA*01:01  HLA-DRB1*04:01     MHCII     PKYVKQNTLKLAT
# 967      HLA-A*02:01             B2M      MHCI         NLVPMVATV
# 42436    HLA-A*03:01             B2M      MHCI         KLGGALQAK
# 17876    HLA-A*02:01             B2M      MHCI         YVLDHLIVV
# 5363     HLA-A*11:01             B2M      MHCI        GTSGSPIVNR
# 84070       HLA-A*02             B2M      MHCI        ELAGIGILTV
# 46270    HLA-A*03:01             B2M      MHCI         KLGGALQAK
# 28305    HLA-A*11:01             B2M      MHCI        AVFDRKSDAK
