# %%
import pandas as pd

df = pd.read_csv("vdj.csv")

# %%
df
# Out:
#        complex.id gene                 cdr3       v.segm      j.segm  \
# 0               0  TRB  CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 1               0  TRB  CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB  CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3               0  TRB  CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 4               0  TRB        CASSFGVEDEQYF   TRBV7-2*01  TRBJ2-7*01
# ...           ...  ...                  ...          ...         ...
# 92766       30592  TRB      CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01
# 92767       30593  TRA         CAPQGATNKLIF  TRAV12-2*01   TRAJ32*01
# 92768       30593  TRB      CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01
# 92769       30594  TRA       CLVGGSGGYNKLIF     TRAV4*01    TRAJ4*01
# 92770       30594  TRB        CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01
#
#            species           mhc.a           mhc.b mhc.class  antigen.epitope  \
# 0      HomoSapiens        HLA-B*08             B2M      MHCI         FLKEKGGL
# 1      HomoSapiens        HLA-B*08             B2M      MHCI         FLKEQGGL
# 2      HomoSapiens        HLA-B*08             B2M      MHCI         FLKETGGL
# 3      HomoSapiens        HLA-B*08             B2M      MHCI         FLKEMGGL
# 4      HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII  LQPFPQPELPYPQPQ
# ...            ...             ...             ...       ...              ...
# 92766  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII    PQQPFPQPEQPFP
# 92767  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII    PQQPFPQPEQPFP
# 92768  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII    PQQPFPQPEQPFP
# 92769  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII    PQQPFPQPEQPFP
# 92770  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII    PQQPFPQPEQPFP
#
#        ...   antigen.species   reference.id  \
# 0      ...             HIV-1  PMID:15596521
# 1      ...             HIV-1  PMID:15596521
# 2      ...             HIV-1  PMID:15596521
# 3      ...             HIV-1  PMID:15596521
# 4      ...  TriticumAestivum  PMID:31956412
# ...    ...               ...            ...
# 92766  ...             Wheat  PMID:33927715
# 92767  ...             Wheat  PMID:33927715
# 92768  ...             Wheat  PMID:33927715
# 92769  ...             Wheat  PMID:33927715
# 92770  ...             Wheat  PMID:33927715
#
#                                                   method  \
# 0      {"frequency": "", "identification": "tetramer-...
# 1      {"frequency": "", "identification": "tetramer-...
# 2      {"frequency": "", "identification": "tetramer-...
# 3      {"frequency": "", "identification": "tetramer-...
# 4      {"frequency": "54/91", "identification": "anti...
# ...                                                  ...
# 92766  {"frequency": "", "identification": "tetramer-...
# 92767  {"frequency": "", "identification": "tetramer-...
# 92768  {"frequency": "", "identification": "tetramer-...
# 92769  {"frequency": "", "identification": "tetramer-...
# 92770  {"frequency": "", "identification": "tetramer-...
#
#                                                     meta  \
# 0      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 1      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 2      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 3      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 4      {"cell.subset": "CD4+CD25+OX40+CD39+", "clone....
# ...                                                  ...
# 92766  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92767  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92768  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92769  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92770  {"cell.subset": "CD4+", "clone.id": "", "donor...
#
#                                                  cdr3fix vdjdb.score  \
# 0      {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...           2
# 1      {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...           2
# 2      {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...           2
# 3      {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...           2
# 4      {"cdr3": "CASSFGVEDEQYF", "cdr3_old": "CASSFGV...           1
# ...                                                  ...         ...
# 92766  {"cdr3": "CASSPGQGGDNEQFF", "cdr3_old": "CASSP...           0
# 92767  {"cdr3": "CAPQGATNKLIF", "cdr3_old": "CAPQGATN...           2
# 92768  {"cdr3": "CASSLGAGGQETQYF", "cdr3_old": "CASSL...           2
# 92769  {"cdr3": "CLVGGSGGYNKLIF", "cdr3_old": "CLVGGS...           0
# 92770  {"cdr3": "CASSSTAQETQYF", "cdr3_old": "CASSSTA...           0
#
#        web.method web.method.seq web.cdr3fix.nc web.cdr3fix.unmp
# 0            sort         sanger             no               no
# 1            sort         sanger             no               no
# 2            sort         sanger             no               no
# 3            sort         sanger             no               no
# 4         culture         sanger             no               no
# ...           ...            ...            ...              ...
# 92766        sort     singlecell             no               no
# 92767        sort     singlecell             no               no
# 92768        sort     singlecell             no               no
# 92769        sort     singlecell             no               no
# 92770        sort     singlecell             no               no
#
# [92771 rows x 21 columns]

# %%
# complex.id: 数据记录的复合体ID，用于唯一标识数据记录。
# gene: TCR的基因类型，如TRA（α链）或TRB（β链）。
# cdr3: TCR中CDR3区的氨基酸序列，这是决定TCR特异性的关键区域。
# v.segm: 变异（V）区基因段的名称，对应于TCRα或β链的V区。
# j.segm: 连接（J）区基因段的名称，对应于TCRα或β链的J区。
# species: TCR来源的物种，如HomoSapiens（人类）。
# mhc.a: 主要组织相容性复合体（MHC）分子的A链类型。
# mhc.b: MHC分子的B链类型或其他相关标记（如B2M，β2-微球蛋白）。
# mhc.class: MHC分子的类别，如MHCI或MHCII。
# antigen.epitope: TCR识别的抗原表位的氨基酸序列。
# antigen.gene: 抗原的基因名称。
# antigen.species: 抗原来源的物种，如HIV-1。
# reference.id: 发表这一数据的文献的参考ID，如PMID:15596521。
# method: 数据收集的方法或技术，例如通过tetramer-sort、sanger测序等。
# meta: 元数据，包含有关样本的额外信息，如细胞亚群、捐献者MHC信息、样本来源等。
# cdr3fix: CDR3区序列修正的信息，包括是否需要修正、修正前后的序列等。
# vdjdb.score: 数据记录的质量评分。
# web.method: 数据提交或验证时使用的网页方法。
# web.method.seq: 与web.method相关的序列信息。
# web.cdr3fix.nc: 网络上CDR3修正的非规范（non-canonical）信息。
# web.cdr3fix.unmp: 网络上CDR3修正的未映射（unmapped）信息。
# complex.id: Complex ID of the data record, used to uniquely identify the data record.
# gene: The gene type of the TCR, such as TRA (alpha chain) or TRB (beta chain).
# cdr3: Amino acid sequence of the CDR3 region in the TCR, which is the key region that determines the specificity of the TCR.
# v.segm: Name of the gene segment of the variant (V) region, corresponding to the V region of the TCR alpha or beta chain.
# j.segm: Name of the gene segment of the junction (J) region, corresponding to the J region of the TCR alpha or beta chain.
# species: The species from which the TCR originated, e.g. HomoSapiens (human).
# mhc.a: A-chain type of the major histocompatibility complex (MHC) molecule.
# mhc.b: B-chain type of MHC molecule or other relevant marker (e.g. B2M, β2-microglobulin).
# mhc.class: Class of the MHC molecule, e.g. MHCI or MHCII.
# antigen.epitope: Amino acid sequence of the antigenic epitope recognised by the TCR.
# antigen.gene: The gene name of the antigen.
# antigen.species: The species from which the antigen originated, e.g. HIV-1.
# reference.id: The reference ID of the literature in which this data was published, e.g. PMID:15596521.
# method: The method or technique used for data collection, e.g. by tetramer-sort, sanger sequencing, etc.
# meta: Metadata containing additional information about the sample, e.g. cell subpopulations, donor MHC information, sample source, etc.
# cdr3fix: information about sequence correction of CDR3 region, including whether correction is needed, sequence before and after correction, etc.
# vdjdb.score: Quality score of the data record.
# web.method: The web method used for data submission or validation.
# web.method.seq: Sequence information associated with the web.method.
# web.cdr3fix.nc: Non-canonical information about CDR3 fixes on the web.
# web.cdr3fix.unmp: Unmapped information for CDR3 fixes on the web.

# %%
df.isnull().sum()
# Out:
# complex.id             0
# gene                   0
# cdr3                   0
# v.segm               101
# j.segm              1145
# species                0
# mhc.a                  0
# mhc.b                  0
# mhc.class              0
# antigen.epitope        0
# antigen.gene          62
# antigen.species        0
# reference.id        1511
# method                 0
# meta                   0
# cdr3fix                0
# vdjdb.score            0
# web.method             0
# web.method.seq         0
# web.cdr3fix.nc         0
# web.cdr3fix.unmp       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92771 entries, 0 to 92770
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   complex.id        92771 non-null  int64
#  1   gene              92771 non-null  object
#  2   cdr3              92771 non-null  object
#  3   v.segm            92670 non-null  object
#  4   j.segm            91626 non-null  object
#  5   species           92771 non-null  object
#  6   mhc.a             92771 non-null  object
#  7   mhc.b             92771 non-null  object
#  8   mhc.class         92771 non-null  object
#  9   antigen.epitope   92771 non-null  object
#  10  antigen.gene      92709 non-null  object
#  11  antigen.species   92771 non-null  object
#  12  reference.id      91260 non-null  object
#  13  method            92771 non-null  object
#  14  meta              92771 non-null  object
#  15  cdr3fix           92771 non-null  object
#  16  vdjdb.score       92771 non-null  int64
#  17  web.method        92771 non-null  object
#  18  web.method.seq    92771 non-null  object
#  19  web.cdr3fix.nc    92771 non-null  object
#  20  web.cdr3fix.unmp  92771 non-null  object
# dtypes: int64(2), object(19)
# memory usage: 14.9+ MB

# %%
# not sure whether we should delete the null-value
df = df.dropna(axis = 0)
df.isnull().sum()
# Out:
# complex.id          0
# gene                0
# cdr3                0
# v.segm              0
# j.segm              0
# species             0
# mhc.a               0
# mhc.b               0
# mhc.class           0
# antigen.epitope     0
# antigen.gene        0
# antigen.species     0
# reference.id        0
# method              0
# meta                0
# cdr3fix             0
# vdjdb.score         0
# web.method          0
# web.method.seq      0
# web.cdr3fix.nc      0
# web.cdr3fix.unmp    0
# dtype: int64

# %%
df
# Out:
#        complex.id gene                 cdr3       v.segm      j.segm  \
# 0               0  TRB  CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 1               0  TRB  CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB  CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3               0  TRB  CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 4               0  TRB        CASSFGVEDEQYF   TRBV7-2*01  TRBJ2-7*01
# ...           ...  ...                  ...          ...         ...
# 92766       30592  TRB      CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01
# 92767       30593  TRA         CAPQGATNKLIF  TRAV12-2*01   TRAJ32*01
# 92768       30593  TRB      CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01
# 92769       30594  TRA       CLVGGSGGYNKLIF     TRAV4*01    TRAJ4*01
# 92770       30594  TRB        CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01
#
#            species           mhc.a           mhc.b mhc.class  antigen.epitope  \
# 0      HomoSapiens        HLA-B*08             B2M      MHCI         FLKEKGGL
# 1      HomoSapiens        HLA-B*08             B2M      MHCI         FLKEQGGL
# 2      HomoSapiens        HLA-B*08             B2M      MHCI         FLKETGGL
# 3      HomoSapiens        HLA-B*08             B2M      MHCI         FLKEMGGL
# 4      HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII  LQPFPQPELPYPQPQ
# ...            ...             ...             ...       ...              ...
# 92766  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII    PQQPFPQPEQPFP
# 92767  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII    PQQPFPQPEQPFP
# 92768  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII    PQQPFPQPEQPFP
# 92769  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII    PQQPFPQPEQPFP
# 92770  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII    PQQPFPQPEQPFP
#
#        ...   antigen.species   reference.id  \
# 0      ...             HIV-1  PMID:15596521
# 1      ...             HIV-1  PMID:15596521
# 2      ...             HIV-1  PMID:15596521
# 3      ...             HIV-1  PMID:15596521
# 4      ...  TriticumAestivum  PMID:31956412
# ...    ...               ...            ...
# 92766  ...             Wheat  PMID:33927715
# 92767  ...             Wheat  PMID:33927715
# 92768  ...             Wheat  PMID:33927715
# 92769  ...             Wheat  PMID:33927715
# 92770  ...             Wheat  PMID:33927715
#
#                                                   method  \
# 0      {"frequency": "", "identification": "tetramer-...
# 1      {"frequency": "", "identification": "tetramer-...
# 2      {"frequency": "", "identification": "tetramer-...
# 3      {"frequency": "", "identification": "tetramer-...
# 4      {"frequency": "54/91", "identification": "anti...
# ...                                                  ...
# 92766  {"frequency": "", "identification": "tetramer-...
# 92767  {"frequency": "", "identification": "tetramer-...
# 92768  {"frequency": "", "identification": "tetramer-...
# 92769  {"frequency": "", "identification": "tetramer-...
# 92770  {"frequency": "", "identification": "tetramer-...
#
#                                                     meta  \
# 0      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 1      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 2      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 3      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 4      {"cell.subset": "CD4+CD25+OX40+CD39+", "clone....
# ...                                                  ...
# 92766  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92767  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92768  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92769  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92770  {"cell.subset": "CD4+", "clone.id": "", "donor...
#
#                                                  cdr3fix vdjdb.score  \
# 0      {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...           2
# 1      {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...           2
# 2      {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...           2
# 3      {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...           2
# 4      {"cdr3": "CASSFGVEDEQYF", "cdr3_old": "CASSFGV...           1
# ...                                                  ...         ...
# 92766  {"cdr3": "CASSPGQGGDNEQFF", "cdr3_old": "CASSP...           0
# 92767  {"cdr3": "CAPQGATNKLIF", "cdr3_old": "CAPQGATN...           2
# 92768  {"cdr3": "CASSLGAGGQETQYF", "cdr3_old": "CASSL...           2
# 92769  {"cdr3": "CLVGGSGGYNKLIF", "cdr3_old": "CLVGGS...           0
# 92770  {"cdr3": "CASSSTAQETQYF", "cdr3_old": "CASSSTA...           0
#
#        web.method web.method.seq web.cdr3fix.nc web.cdr3fix.unmp
# 0            sort         sanger             no               no
# 1            sort         sanger             no               no
# 2            sort         sanger             no               no
# 3            sort         sanger             no               no
# 4         culture         sanger             no               no
# ...           ...            ...            ...              ...
# 92766        sort     singlecell             no               no
# 92767        sort     singlecell             no               no
# 92768        sort     singlecell             no               no
# 92769        sort     singlecell             no               no
# 92770        sort     singlecell             no               no
#
# [90071 rows x 21 columns]

# %% [markdown]
# Limatation:
#     1. Disregarding the length distribution of CDR3.The variations in its length may be associated with specificity.
#     2. Unable to capture the correlation among TCR sequences.
#     3. When the matrix generated becomes excessively sparse, the computational resources required become too extensive.
#
# Possible solution:
#     Embedding layer. The embedding layer can map high-dimensional vectors represented in one-hot encoding to a lower-dimensional continuous space, thereby preserving the semantic information of the sequences while reducing dimensionality.
#         嵌入层通过线性变化将高维向量映射到低维连续空间，模型还能学习保留序列之间的关系

# %%
df.loc[:, 'species'] = df['species'].astype('category').cat.codes
df.loc[:, 'gene'] = df['gene'].astype('category').cat.codes
df.loc[:, 'mhc.class'] = df['mhc.class'].astype('category').cat.codes
df.loc[:, 'web.method'] = df['web.method'].astype('category').cat.codes
df.loc[:, 'web.method.seq'] = df['web.method.seq'].astype('category').cat.codes
df.loc[:, 'web.cdr3fix.nc'] = df['web.cdr3fix.nc'].astype('category').cat.codes
df.loc[:, 'web.cdr3fix.unmp'] = df['web.cdr3fix.unmp'].astype('category').cat.codes
df.head()
# Out:
# /var/folders/qj/hrn4_tz55q59b0s8ll2z634m0000gn/T/ipykernel_88769/4293756135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'species'] = df['species'].astype('category').cat.codes
# /var/folders/qj/hrn4_tz55q59b0s8ll2z634m0000gn/T/ipykernel_88769/4293756135.py:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'species'] = df['species'].astype('category').cat.codes
# /var/folders/qj/hrn4_tz55q59b0s8ll2z634m0000gn/T/ipykernel_88769/4293756135.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'gene'] = df['gene'].astype('category').cat.codes
# /var/folders/qj/hrn4_tz55q59b0s8ll2z634m0000gn/T/ipykernel_88769/4293756135.py:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'gene'] = df['gene'].astype('category').cat.codes
# /var/folders/qj/hrn4_tz55q59b0s8ll2z634m0000gn/T/ipykernel_88769/4293756135.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'mhc.class'] = df['mhc.class'].astype('category').cat.codes
# /var/folders/qj/hrn4_tz55q59b0s8ll2z634m0000gn/T/ipykernel_88769/4293756135.py:3: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'mhc.class'] = df['mhc.class'].astype('category').cat.codes
# /var/folders/qj/hrn4_tz55q59b0s8ll2z634m0000gn/T/ipykernel_88769/4293756135.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'web.method'] = df['web.method'].astype('category').cat.codes
# /var/folders/qj/hrn4_tz55q59b0s8ll2z634m0000gn/T/ipykernel_88769/4293756135.py:4: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'web.method'] = df['web.method'].astype('category').cat.codes
# /var/folders/qj/hrn4_tz55q59b0s8ll2z634m0000gn/T/ipykernel_88769/4293756135.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'web.method.seq'] = df['web.method.seq'].astype('category').cat.codes
# /var/folders/qj/hrn4_tz55q59b0s8ll2z634m0000gn/T/ipykernel_88769/4293756135.py:5: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'web.method.seq'] = df['web.method.seq'].astype('category').cat.codes
# /var/folders/qj/hrn4_tz55q59b0s8ll2z634m0000gn/T/ipykernel_88769/4293756135.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'web.cdr3fix.nc'] = df['web.cdr3fix.nc'].astype('category').cat.codes
# /var/folders/qj/hrn4_tz55q59b0s8ll2z634m0000gn/T/ipykernel_88769/4293756135.py:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'web.cdr3fix.nc'] = df['web.cdr3fix.nc'].astype('category').cat.codes
# /var/folders/qj/hrn4_tz55q59b0s8ll2z634m0000gn/T/ipykernel_88769/4293756135.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'web.cdr3fix.unmp'] = df['web.cdr3fix.unmp'].astype('category').cat.codes
# /var/folders/qj/hrn4_tz55q59b0s8ll2z634m0000gn/T/ipykernel_88769/4293756135.py:7: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'web.cdr3fix.unmp'] = df['web.cdr3fix.unmp'].astype('category').cat.codes
#    complex.id  gene                 cdr3      v.segm      j.segm  species  \
# 0           0     1  CASSFEAGQGFFSNQPQHF   TRBV13*01  TRBJ1-5*01        0
# 1           0     1  CASSFEAGQGFFSNQPQHF   TRBV13*01  TRBJ1-5*01        0
# 2           0     1  CASSFEAGQGFFSNQPQHF   TRBV13*01  TRBJ1-5*01        0
# 3           0     1  CASSFEAGQGFFSNQPQHF   TRBV13*01  TRBJ1-5*01        0
# 4           0     1        CASSFGVEDEQYF  TRBV7-2*01  TRBJ2-7*01        0
#
#             mhc.a           mhc.b  mhc.class  antigen.epitope  ...  \
# 0        HLA-B*08             B2M          0         FLKEKGGL  ...
# 1        HLA-B*08             B2M          0         FLKEQGGL  ...
# 2        HLA-B*08             B2M          0         FLKETGGL  ...
# 3        HLA-B*08             B2M          0         FLKEMGGL  ...
# 4  HLA-DQA1*05:01  HLA-DQB1*02:01          1  LQPFPQPELPYPQPQ  ...
#
#     antigen.species   reference.id  \
# 0             HIV-1  PMID:15596521
# 1             HIV-1  PMID:15596521
# 2             HIV-1  PMID:15596521
# 3             HIV-1  PMID:15596521
# 4  TriticumAestivum  PMID:31956412
#
#                                               method  \
# 0  {"frequency": "", "identification": "tetramer-...
# 1  {"frequency": "", "identification": "tetramer-...
# 2  {"frequency": "", "identification": "tetramer-...
# 3  {"frequency": "", "identification": "tetramer-...
# 4  {"frequency": "54/91", "identification": "anti...
#
#                                                 meta  \
# 0  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 1  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 2  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 3  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 4  {"cell.subset": "CD4+CD25+OX40+CD39+", "clone....
#
#                                              cdr3fix vdjdb.score  web.method  \
# 0  {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...           2           2
# 1  {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...           2           2
# 2  {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...           2           2
# 3  {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...           2           2
# 4  {"cdr3": "CASSFGVEDEQYF", "cdr3_old": "CASSFGV...           1           0
#
#    web.method.seq  web.cdr3fix.nc  web.cdr3fix.unmp
# 0               2               0                 0
# 1               2               0                 0
# 2               2               0                 0
# 3               2               0                 0
# 4               2               0                 0
#
# [5 rows x 21 columns]

# %%
# Basic statistics of the dataset
basic_stats = df.describe(include='all')

# Display basic statistics to get an overview of the dataset
basic_stats
# Out:
#           complex.id          gene           cdr3     v.segm      j.segm  \
# count   90071.000000  90071.000000          90071      90071       90071
# unique           NaN           NaN          66920        222          71
# top              NaN           NaN  CASSIRSSYEQYF  TRBV19*01  TRBJ2-7*01
# freq             NaN           NaN            361       5948        9025
# mean    10222.049439      0.596885            NaN        NaN         NaN
# std     10210.030068      0.490526            NaN        NaN         NaN
# min         0.000000      0.000000            NaN        NaN         NaN
# 25%         0.000000      0.000000            NaN        NaN         NaN
# 50%      7795.000000      1.000000            NaN        NaN         NaN
# 75%     19155.500000      1.000000            NaN        NaN         NaN
# max     30594.000000      1.000000            NaN        NaN         NaN
#
#              species        mhc.a  mhc.b     mhc.class antigen.epitope  ...  \
# count   90071.000000        90071  90071  90071.000000           90071  ...
# unique           NaN          117     45           NaN            1148  ...
# top              NaN  HLA-A*03:01    B2M           NaN       KLGGALQAK  ...
# freq             NaN        28959  85804           NaN           27669  ...
# mean        0.139068          NaN    NaN      0.047374             NaN  ...
# std         0.486044          NaN    NaN      0.212438             NaN  ...
# min         0.000000          NaN    NaN      0.000000             NaN  ...
# 25%         0.000000          NaN    NaN      0.000000             NaN  ...
# 50%         0.000000          NaN    NaN      0.000000             NaN  ...
# 75%         0.000000          NaN    NaN      0.000000             NaN  ...
# max         2.000000          NaN    NaN      1.000000             NaN  ...
#
#        antigen.species                                       reference.id  \
# count            90071                                              90071
# unique              41                                                305
# top                CMV  https://www.10xgenomics.com/resources/applicat...
# freq             37961                                              40357
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#                                                    method  \
# count                                               90071
# unique                                               8423
# top     {"frequency": "1/25584", "identification": "de...
# freq                                                20182
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                      meta  \
# count                                               90071
# unique                                               4194
# top     {"cell.subset": "", "clone.id": "", "donor.MHC...
# freq                                                22219
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                   cdr3fix   vdjdb.score  \
# count                                               90071  90071.000000
# unique                                              69726           NaN
# top     {"cdr3": "CASSIRSSYEQYF", "cdr3_old": "CASSIRS...           NaN
# freq                                                  323           NaN
# mean                                                  NaN      0.195690
# std                                                   NaN      0.564668
# min                                                   NaN      0.000000
# 25%                                                   NaN      0.000000
# 50%                                                   NaN      0.000000
# 75%                                                   NaN      0.000000
# max                                                   NaN      3.000000
#
#           web.method  web.method.seq  web.cdr3fix.nc  web.cdr3fix.unmp
# count   90071.000000    90071.000000    90071.000000      90071.000000
# unique           NaN             NaN             NaN               NaN
# top              NaN             NaN             NaN               NaN
# freq             NaN             NaN             NaN               NaN
# mean        1.940502        2.214320        0.001499          0.018574
# std         0.330698        1.222712        0.038686          0.135016
# min         0.000000        0.000000        0.000000          0.000000
# 25%         2.000000        2.000000        0.000000          0.000000
# 50%         2.000000        3.000000        0.000000          0.000000
# 75%         2.000000        3.000000        0.000000          0.000000
# max         2.000000        3.000000        1.000000          1.000000
#
# [11 rows x 21 columns]

# %%
# gene and antigen.epitope
import matplotlib.pyplot as plt
import seaborn as sns

# Filter out the rows with the most common epitopes for clarity in visualization
top_epitopes = df['antigen.epitope'].value_counts().nlargest(10).index

# Data for visualization
viz_data = df[df['antigen.epitope'].isin(top_epitopes)]

# Plotting gene vs antigen.epitope
plt.figure(figsize=(12, 8))
sns.countplot(data=viz_data, y='antigen.epitope', hue='gene', order=top_epitopes)
plt.title('Distribution of Gene Types for Top 10 Antigen Epitopes')
plt.xlabel('Count')
plt.ylabel('Antigen Epitope')
plt.legend(title='Gene', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

plt.show()

# %%
# species and antigen.epitope

# Plotting species vs antigen.epitope for top epitopes
plt.figure(figsize=(12, 8))
sns.countplot(data=viz_data, y='antigen.epitope', hue='species', order=top_epitopes)
plt.title('Distribution of Species for Top 10 Antigen Epitopes')
plt.xlabel('Count')
plt.ylabel('Antigen Epitope')
plt.legend(title='Species', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

plt.show()

# %%
# 探索MHC类别（mhc.class）与抗原表位（antigen.epitope）之间的关系
# Explore the relationship between MHC class (mhc.class) and antigenic epitope (antigen.epitope)

# Plotting mhc.class vs antigen.epitope for top epitopes
plt.figure(figsize=(12, 8))
sns.countplot(data=viz_data, y='antigen.epitope', hue='mhc.class', order=top_epitopes)
plt.title('Distribution of MHC Class for Top 10 Antigen Epitopes')
plt.xlabel('Count')
plt.ylabel('Antigen Epitope')
plt.legend(title='MHC Class', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

plt.show()

# %%
# We can further explore the relationship between different kinds 
# of MHCs and TCR gene segments (e.g. v.segm and j.segm) and how they affect VDJDB scores
# First, we can create a new column to represent the V and J combination
df['vj_combination'] = df['v.segm'] + '_' + df['j.segm']

# 为了简化分析，我们可能只关注那些最常见的VJ组合
# To simplify the analysis, we may focus only on those VJ combinations that are most common
top_vj_combinations = df['vj_combination'].value_counts().nlargest(10).index

# 筛选出这些组合的数据
# Sift through the data for these combinations
filtered_vj_df = df[df['vj_combination'].isin(top_vj_combinations)]

# 使用散点图来展示VDJDB评分与VJ组合之间的关系，我们也可以按照MHC类别进行着色
# Use a scatterplot to show the relationship between VDJDB scores 
# and VJ combinations, which we can also colour by MHC category
plt.figure(figsize=(16, 10))
sns.scatterplot(x='vj_combination', y='vdjdb.score', hue='mhc.class', data=filtered_vj_df, style='mhc.class', s=100)
plt.title('VDJDB Score by VJ Combination and MHC Class')
plt.xlabel('VJ Combination')
plt.ylabel('VDJDB Score')
plt.xticks(rotation=45)
plt.legend(title='MHC Class')
plt.tight_layout()
# Out:
# /var/folders/qj/hrn4_tz55q59b0s8ll2z634m0000gn/T/ipykernel_88769/2067859463.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vj_combination'] = df['v.segm'] + '_' + df['j.segm']

# %%
# TCR CDR3序列长度分布图
# TCR CDR3 sequence length distribution map
df['cdr3_length'] = df['cdr3'].apply(len)
plt.figure(figsize=(10, 6))
plt.hist(df['cdr3_length'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of CDR3 Lengths')
plt.xlabel('CDR3 Length')
plt.ylabel('Frequency')
plt.show()
# Out:
# /var/folders/qj/hrn4_tz55q59b0s8ll2z634m0000gn/T/ipykernel_88769/2718206076.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cdr3_length'] = df['cdr3'].apply(len)

# %%
# V和J区段使用频率图
# Frequency map of use of V and J sectors
plt.figure(figsize=(12, 8))
df['v.segm'].value_counts().nlargest(10).plot(kind='bar', color='orange')
plt.title('Top 10 Most Frequent V Segments')
plt.xlabel('V Segment')
plt.ylabel('Frequency')
plt.show()

plt.figure(figsize=(12, 8))
df['j.segm'].value_counts().nlargest(10).plot(kind='bar', color='green')
plt.title('Top 10 Most Frequent J Segments')
plt.xlabel('J Segment')
plt.ylabel('Frequency')
plt.show()

# %%
# MHC类别与VDJDB评分的关系
# of MHC categories in relation to VDJDB scores
plt.figure(figsize=(10, 6))
boxplot = df.boxplot(column='vdjdb.score', by='mhc.class')
plt.title('VDJDB Score by MHC Class')
plt.suptitle('')  
plt.xlabel('MHC Class')
plt.ylabel('VDJDB Score')
plt.show()

# %%
# 分析cdr3序列长度与vdjdb.score之间的关系
# Analyse the relationship between cdr3 sequence length and vdjdb.score
# 计算cdr3序列长度
df['cdr3_length'] = df['cdr3'].apply(len)

# 绘制cdr3长度与vdjdb.score的关系图
plt.figure(figsize=(12, 6))
sns.scatterplot(x='cdr3_length', y='vdjdb.score', data=df, alpha=0.6)
plt.title('CDR3 Length vs VDJDB Score')
plt.xlabel('CDR3 Length')
plt.ylabel('VDJDB Score')
plt.show()
# Out:
# /var/folders/qj/hrn4_tz55q59b0s8ll2z634m0000gn/T/ipykernel_88769/861899742.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cdr3_length'] = df['cdr3'].apply(len)

# %%
# 分析v.segm和j.segm的使用频率，以及这些频率如何与VDJDB评分相关
# 绘制v.segm和j.segm使用频率的直方图
# Analyse the frequency of use of v.segm and j.segm and how these frequencies correlate with VDJDB scores
# Plot histograms of v.segm and j.segm usage frequencies
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
sns.countplot(y='v.segm', data=df, order=pd.value_counts(df['v.segm']).iloc[:10].index, ax=ax[0])
ax[0].set_title('Top 10 V Segment Usage')
ax[0].set_xlabel('Frequency')
ax[0].set_ylabel('V Segment')
sns.countplot(y='j.segm', data=df, order=pd.value_counts(df['j.segm']).iloc[:10].index, ax=ax[1])
ax[1].set_title('Top 10 J Segment Usage')
ax[1].set_xlabel('Frequency')
ax[1].set_ylabel('J Segment')
plt.tight_layout()
plt.show()

# %%
# MHC类别与评分关系
# MHC categories in relation to scores
plt.figure(figsize=(10, 6))
sns.boxplot(x='mhc.class', y='vdjdb.score', data=df)
plt.title('VDJDB Score Distribution Across MHC Classes')
plt.xlabel('MHC Class')
plt.ylabel('VDJDB Score')
plt.show()

# %% [markdown]
# 在我的项目中，我采用了基本的数据编码和统计分析方法，这可能未能充分捕捉分类数据间的复杂关系和序列信息。虽然利用了多维可视化，但更高级的分析如聚类或降维可能揭示更深入的洞察。此外，我未详细探讨模型优化和验证步骤，这对于确保预测的准确性和泛化能力至关重要。我意识到，考虑数据的生物学特性和免疫学背景对于理解TCR数据的复杂性非常重要。
# While I have utilised multidimensional visualisations, more advanced analyses such as clustering or dimensionality reduction may reveal deeper insights. In addition, I have not explored in detail the model optimisation and validation steps, which are crucial to ensure the accuracy and generalisability of predictions.

# %% [markdown]
# 在项目中，我进行了数据预处理，将关键文本特征转换为数值编码，并通过描述性统计分析和多维可视化技术探索了数据集的关键特征。我分析了基因类型、物种、MHC类别与抗原表位的分布关系，创建并研究了VJ组合与VDJDB评分的相关性。通过直方图和散点图，我还探讨了CDR3序列长度、V/J区段使用频率与评分之间的关系，为理解TCR数据集的复杂性提供了深入见解，并为机器学习模型的开发准备了数据。
# In the project, I performed data preprocessing, converted key text features into numerical coding, and explored the key features of the dataset through descriptive statistical analysis and multidimensional visualization techniques. I analyzed the distribution of genotypes, species, MHC categories and epitopes, and created and studied the correlation between VJ combinations and VDJDB scores. Using histograms and scatterplots, I also explored the relationship between CDR3 sequence length, frequency of use of V/J segments, and ratings, providing insight into the complexity of TCR datasets and preparing data for the development of machine learning models.

# %%
from collections import Counter
import matplotlib.pyplot as plt

def generate_kmers(sequence, k):
    """Generate k-mers for a given sequence."""
    return [sequence[i:i+k] for i in range(len(sequence)-k+1)]

# Apply the function to generate 4-mers for each cdr3 sequence
k = 4
cdr3_sequences = df['cdr3']
all_kmers = [kmer for seq in cdr3_sequences for kmer in generate_kmers(seq, k)]

# Count the frequency of each 4-mer
kmer_counts = Counter(all_kmers)

# Convert the counter object to a dataframe for easy plotting
kmer_df = pd.DataFrame(kmer_counts.items(), columns=['4-mer', 'Frequency']).sort_values(by='Frequency', ascending=False)

# Plot the top 20 most frequent 4-mers
plt.figure(figsize=(10, 8))
plt.bar(kmer_df['4-mer'][:20], kmer_df['Frequency'][:20], color='skyblue')
plt.xlabel('4-mer')
plt.ylabel('Frequency')
plt.title('Top 20 Most Frequent 4-mers in CDR3 Sequences')
plt.xticks(rotation=45)
plt.show()

# %%
# Apply the function to generate 3-mers for each cdr3 sequence
k = 3
all_kmers_3 = [kmer for seq in cdr3_sequences for kmer in generate_kmers(seq, k)]

# Count the frequency of each 3-mer
kmer_counts_3 = Counter(all_kmers_3)

# Convert the counter object to a dataframe for easy plotting
kmer_df_3 = pd.DataFrame(kmer_counts_3.items(), columns=['3-mer', 'Frequency']).sort_values(by='Frequency', ascending=False)

# Plot the top 20 most frequent 3-mers
plt.figure(figsize=(10, 8))
plt.bar(kmer_df_3['3-mer'][:20], kmer_df_3['Frequency'][:20], color='lightgreen')
plt.xlabel('3-mer')
plt.ylabel('Frequency')
plt.title('Top 20 Most Frequent 3-mers in CDR3 Sequences')
plt.xticks(rotation=45)
plt.show()

# %%
# Apply the function to generate 5-mers for each cdr3 sequence
k = 5
all_kmers_5 = [kmer for seq in cdr3_sequences for kmer in generate_kmers(seq, k)]

# Count the frequency of each 5-mer
kmer_counts_5 = Counter(all_kmers_5)

# Convert the counter object to a dataframe for easy plotting
kmer_df_5 = pd.DataFrame(kmer_counts_5.items(), columns=['5-mer', 'Frequency']).sort_values(by='Frequency', ascending=False)

# Plot the top 20 most frequent 5-mers
plt.figure(figsize=(10, 8))
plt.bar(kmer_df_5['5-mer'][:20], kmer_df_5['Frequency'][:20], color='lightgreen')
plt.xlabel('5-mer')
plt.ylabel('Frequency')
plt.title('Top 20 Most Frequent 5-mers in CDR3 Sequences')
plt.xticks(rotation=45)
plt.show()

# %%
# Apply the function to generate 6-mers for each cdr3 sequence
k = 6
all_kmers_6 = [kmer for seq in cdr3_sequences for kmer in generate_kmers(seq, k)]

# Count the frequency of each 6-mer
kmer_counts_6 = Counter(all_kmers_6)

# Convert the counter object to a dataframe for easy plotting
kmer_df_6 = pd.DataFrame(kmer_counts_6.items(), columns=['6-mer', 'Frequency']).sort_values(by='Frequency', ascending=False)

# Plot the top 20 most frequent 6-mers
plt.figure(figsize=(10, 8))
plt.bar(kmer_df_6['6-mer'][:20], kmer_df_6['Frequency'][:20], color='lightgreen')
plt.xlabel('6-mer')
plt.ylabel('Frequency')
plt.title('Top 20 Most Frequent 6-mers in CDR3 Sequences')
plt.xticks(rotation=45)
plt.show()

# %%
# Apply the function to generate 2-mers for each cdr3 sequence
k = 2
all_kmers_2 = [kmer for seq in cdr3_sequences for kmer in generate_kmers(seq, k)]

# Count the frequency of each 2-mer
kmer_counts_2 = Counter(all_kmers_2)

# Convert the counter object to a dataframe for easy plotting
kmer_df_2 = pd.DataFrame(kmer_counts_2.items(), columns=['2-mer', 'Frequency']).sort_values(by='Frequency', ascending=False)

# Plot the top 20 most frequent 2-mers
plt.figure(figsize=(10, 8))
plt.bar(kmer_df_2['2-mer'][:20], kmer_df_2['Frequency'][:20], color='lightgreen')
plt.xlabel('2-mer')
plt.ylabel('Frequency')
plt.title('Top 20 Most Frequent 2-mers in CDR3 Sequences')
plt.xticks(rotation=45)
plt.show()
